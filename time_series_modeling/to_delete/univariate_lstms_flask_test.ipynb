# %%
import numpy as np
import pandas as pd  
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
from scipy.stats import pearsonr 
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from statsmodels.tsa.arima.model import ARIMA
import xgboost as xgb
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, Bidirectional
from math import sqrt
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
# Out:
# 2024-03-28 13:18:31.364629: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import Dense, LSTM, Dropout, Bidirectional

# %% [markdown]
# # USDC Univariate LSTM Time Series
#
# Approximately 2,000 samples

# %%
def json_to_prices(json):
    df = pd.read_json(json)
    prices = df['prices']
    coin_prices = pd.DataFrame(prices.tolist(), columns=['time', 'price'])
    prices = coin_prices['price']
    return prices

# %%
prices = json_to_prices('time_series_modeling/data/usdc90days.json')

# %%
def normalize_prices(prices):
    normalized_prices = (prices - np.mean(prices)) / np.std(prices)
    return normalized_prices

# %%
# Normalize the prices data
normalized_prices = (prices - np.mean(prices)) / np.std(prices)
print(normalized_prices)
# Out:
# 0       0.313974
# 1      -0.139964
# 2      -0.707387
# 3      -0.026480
# 4      -1.274809
#           ...
# 2155   -2.977077
# 2156   -0.026480
# 2157    0.540943
# 2158   -1.501778
# 2159    0.087005
# Name: price, Length: 2160, dtype: float64

# %%
def split_data(normalized_prices, split=0.8):
    train_size = int(len(normalized_prices) * split)
    test_size = len(normalized_prices) - train_size
    
    training_data = normalized_prices[0:train_size]
    test_data = normalized_prices[train_size:len(normalized_prices)]
    return training_data, test_data

# %%
def create_dataset_helper(data, time_step=1):
    X, y = [], []
    data = data.reset_index(drop=True)

    for i in range(len(data) - time_step):      
        X.append(data[i:(i + time_step)])
        y.append(data[i + time_step])
    return np.array(X), np.array(y)

# %%
def create_dataset(data, time_steps=1):
    X, y = create_dataset_helper(data, time_steps)
    X = X.reshape(X.shape[0], X.shape[1], 1)
    return X, y

# %%
time_step = 10 # the number of time steps you're looking at to predict the next step.

# Split the data into training and testing data
training_data, test_data = split_data(normalized_prices)
X_train, y_train = create_dataset(training_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (1718, 10, 1) (1718,) (422, 10, 1) (422,)

# %%
def create_model():
    model = Sequential()
    model.add(LSTM(50, return_sequences=True, input_shape=(time_step, 1)))
    model.add(LSTM(50, return_sequences=False))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
model = create_model()
model.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_27 (LSTM)              (None, 10, 50)            10400
#
#  lstm_28 (LSTM)              (None, 50)                20200
#
#  dense_17 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 30651 (119.73 KB)
# Trainable params: 30651 (119.73 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1)
# Out:
# Epoch 1/50
# 54/54 [==============================] - 4s 8ms/step - loss: 0.9145
# Epoch 2/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.9109
# Epoch 3/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.9112
# Epoch 4/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.9122
# Epoch 5/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.9107
# Epoch 6/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.9097
# Epoch 7/50
# 54/54 [==============================] - 0s 9ms/step - loss: 0.9076
# Epoch 8/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.9112
# Epoch 9/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.9076
# Epoch 10/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.9088
# Epoch 11/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.9080
# Epoch 12/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.9063
# Epoch 13/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.9068
# Epoch 14/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.9067
# Epoch 15/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.9076
# Epoch 16/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.9053
# Epoch 17/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.9074
# Epoch 18/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.9050
# Epoch 19/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.9047
# Epoch 20/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.9030
# Epoch 21/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.9028
# Epoch 22/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.9013
# Epoch 23/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.8999
# Epoch 24/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.8988
# Epoch 25/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.8993
# Epoch 26/50
# 54/54 [==============================] - 1s 10ms/step - loss: 0.8971
# Epoch 27/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.8943
# Epoch 28/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.8967
# Epoch 29/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.8921
# Epoch 30/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.8899
# Epoch 31/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.8895
# Epoch 32/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.8903
# Epoch 33/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.8851
# Epoch 34/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.8850
# Epoch 35/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.8805
# Epoch 36/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.8794
# Epoch 37/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.8758
# Epoch 38/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.8717
# Epoch 39/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.8703
# Epoch 40/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.8668
# Epoch 41/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.8676
# Epoch 42/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.8605
# Epoch 43/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.8523
# Epoch 44/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.8480
# Epoch 45/50
# 54/54 [==============================] - 0s 9ms/step - loss: 0.8434
# Epoch 46/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.8391
# Epoch 47/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.8368
# Epoch 48/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.8287
# Epoch 49/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.8264
# Epoch 50/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.8154

# %%
def predictions(model, X_train, y_train, X_test, y_test, prices):
    train_predictions = model.predict(X_train)
    test_predictions = model.predict(X_test)
    
    train_predict = (train_predictions * np.std(prices)) + np.mean(prices)
    y_train = (y_train * np.std(prices)) + np.mean(prices)
    test_predict = (test_predictions * np.std(prices)) + np.mean(prices)
    y_test = (y_test * np.std(prices)) + np.mean(prices)
    
    train_score = sqrt(mean_squared_error(y_train, train_predict))
    print('Train Score: %.20f RMSE' % (train_score))
    test_score = sqrt(mean_squared_error(y_test, test_predict))
    print('Test Score: %.20f RMSE' % (test_score))
    print('Test Predictions: ' + str(test_predict))
    return train_predict, test_predict

# %%
def plot_time_series(train_predict, test_predict, prices, time_step=10):
    train_predict_flattened = train_predict.flatten()
    test_predict_flattened = test_predict.flatten()
    train_size = len(train_predict)
    test_size = len(test_predict)
    
    plt.figure(figsize=(10, 6))
    plt.plot(prices, color='blue', label='Actual Price')
    plt.plot(range(time_step, train_size + time_step), train_predict_flattened, color='green', label='Train Predicted Price')
    plt.plot(range(train_size + time_step, train_size + time_step + test_size), test_predict_flattened, color='red', label='Test Predicted Price')

    plt.title('USDC Price Prediction')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# %%
train_predict, test_predict = predictions(model, X_train, y_train, X_test, y_test, prices)
# Out:
# 54/54 [==============================] - 1s 4ms/step
# 14/14 [==============================] - 0s 3ms/step
# Train Score: 0.00079637113500502553 RMSE
# Test Score: 0.00107860277806733876 RMSE

# %%
# flatten the predictions
train_predict_flattened = train_predict.flatten()
test_predict_flattened = test_predict.flatten()
train_size = len(train_predict)
test_size = len(test_predict)

# %%
# graph the results

# reshape train_predict and test_predict to the shape of prices

plt.figure(figsize=(10, 6))
plt.plot(prices, color='blue', label='Actual Price')
plt.plot(range(time_step, train_size + time_step), train_predict_flattened, color='green', label='Train Predicted Price')
plt.plot(range(train_size + time_step, train_size + time_step + test_size), test_predict_flattened, color='red', label='Test Predicted Price')

plt.title('USDC Price Prediction')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# # Ethereum Univariate LSTM Time Series

# %%
time_step = 10

prices = json_to_prices('time_series_modeling/data/ethereum90days.json')
normalized_prices = normalize_prices(prices)
training_data, test_data = split_data(normalized_prices)
X_train, y_train = create_dataset(training_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)
lstm = create_model()

lstm.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 54/54 [==============================] - 5s 19ms/step - loss: 0.0631 - val_loss: 0.4438
# Epoch 2/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0110 - val_loss: 0.3967
# Epoch 3/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0104 - val_loss: 0.3468
# Epoch 4/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.0095 - val_loss: 0.3417
# Epoch 5/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0087 - val_loss: 0.2704
# Epoch 6/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0082 - val_loss: 0.3184
# Epoch 7/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0071 - val_loss: 0.2737
# Epoch 8/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0064 - val_loss: 0.3184
# Epoch 9/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0061 - val_loss: 0.3040
# Epoch 10/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0057 - val_loss: 0.3021
# Epoch 11/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0056 - val_loss: 0.2039
# Epoch 12/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0054 - val_loss: 0.1848
# Epoch 13/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0054 - val_loss: 0.2117
# Epoch 14/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.0051 - val_loss: 0.2010
# Epoch 15/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0051 - val_loss: 0.2240
# Epoch 16/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0047 - val_loss: 0.1775
# Epoch 17/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0045 - val_loss: 0.1706
# Epoch 18/50
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0043 - val_loss: 0.1859
# Epoch 19/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0040 - val_loss: 0.1577
# Epoch 20/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.0038 - val_loss: 0.1613
# Epoch 21/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.0037 - val_loss: 0.1451
# Epoch 22/50
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0036 - val_loss: 0.1343
# Epoch 23/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.0035 - val_loss: 0.1149
# Epoch 24/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0033 - val_loss: 0.1010
# Epoch 25/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0032 - val_loss: 0.0937
# Epoch 26/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0031 - val_loss: 0.0390
# Epoch 27/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0029 - val_loss: 0.0836
# Epoch 28/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.1113
# Epoch 29/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.0029 - val_loss: 0.1078
# Epoch 30/50
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0027 - val_loss: 0.1250
# Epoch 31/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.0028 - val_loss: 0.1432
# Epoch 32/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0027 - val_loss: 0.1173
# Epoch 33/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.0026 - val_loss: 0.0989
# Epoch 34/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0638
# Epoch 35/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.0790
# Epoch 36/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.0732
# Epoch 37/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.1255
# Epoch 38/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.1339
# Epoch 39/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0875
# Epoch 40/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.1268
# Epoch 41/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.0672
# Epoch 42/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.0026 - val_loss: 0.1187
# Epoch 43/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.1155
# Epoch 44/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.0513
# Epoch 45/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.1136
# Epoch 46/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.0026 - val_loss: 0.0694
# Epoch 47/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.0818
# Epoch 48/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.0988
# Epoch 49/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.1174
# Epoch 50/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.1136

# %%
train_predict, test_predict = predictions(lstm, X_train, y_train, X_test, y_test, prices)
# Out:
# 54/54 [==============================] - 0s 3ms/step
# 14/14 [==============================] - 0s 3ms/step
# Train Score: 12.76268769449559137286 RMSE
# Test Score: 86.21029180163651517432 RMSE
# Test Predictions: [[2488.8237]
#  [2489.7744]
#  [2492.1084]
#  [2492.4563]
#  [2491.6953]
#  [2485.3828]
#  [2491.7234]
#  [2494.125 ]
#  [2506.98  ]
#  [2509.8015]
#  [2499.4124]
#  [2498.521 ]
#  [2500.404 ]
#  [2505.5698]
#  [2505.3398]
#  [2524.4731]
#  [2516.536 ]
#  [2522.0706]
#  [2526.793 ]
#  [2525.4949]
#  [2524.1443]
#  [2521.4954]
#  [2522.284 ]
#  [2529.119 ]
#  [2522.0342]
#  [2512.281 ]
#  [2513.636 ]
#  [2509.808 ]
#  [2508.1272]
#  [2511.3687]
#  [2513.061 ]
#  [2507.6558]
#  [2494.8992]
#  [2503.034 ]
#  [2499.9927]
#  [2506.53  ]
#  [2510.8645]
#  [2513.7188]
#  [2499.916 ]
#  [2499.9434]
#  [2493.5818]
#  [2494.4343]
#  [2494.689 ]
#  [2499.9507]
#  [2489.9353]
#  [2475.6155]
#  [2478.4546]
#  [2485.1587]
#  [2490.219 ]
#  [2485.4392]
#  [2524.5818]
#  [2555.8179]
#  [2550.343 ]
#  [2596.2617]
#  [2612.0056]
#  [2608.84  ]
#  [2630.2007]
#  [2623.7869]
#  [2648.3276]
#  [2648.2678]
#  [2656.2158]
#  [2664.6245]
#  [2647.7605]
#  [2632.1816]
#  [2637.9517]
#  [2641.3718]
#  [2635.8938]
#  [2639.653 ]
#  [2650.493 ]
#  [2666.9792]
#  [2655.4707]
#  [2667.6199]
#  [2662.519 ]
#  [2631.958 ]
#  [2619.2378]
#  [2624.6497]
#  [2600.1921]
#  [2610.2986]
#  [2622.6885]
#  [2608.386 ]
#  [2620.79  ]
#  [2624.0127]
#  [2629.1067]
#  [2633.062 ]
#  [2622.446 ]
#  [2616.4717]
#  [2625.179 ]
#  [2629.6921]
#  [2620.611 ]
#  [2632.7144]
#  [2636.1414]
#  [2644.364 ]
#  [2695.429 ]
#  [2724.4182]
#  [2733.0493]
#  [2737.3267]
#  [2723.521 ]
#  [2737.0674]
#  [2740.0527]
#  [2717.7537]
#  [2722.1082]
#  [2720.5996]
#  [2725.295 ]
#  [2736.9014]
#  [2736.8894]
#  [2755.4453]
#  [2746.068 ]
#  [2750.8606]
#  [2783.0095]
#  [2753.7798]
#  [2760.8188]
#  [2769.2046]
#  [2753.5461]
#  [2741.82  ]
#  [2746.8254]
#  [2744.2605]
#  [2753.0544]
#  [2756.375 ]
#  [2768.5872]
#  [2762.1501]
#  [2763.35  ]
#  [2775.9954]
#  [2804.0347]
#  [2788.46  ]
#  [2791.088 ]
#  [2784.3   ]
#  [2782.188 ]
#  [2794.3062]
#  [2789.0127]
#  [2779.6587]
#  [2776.563 ]
#  [2781.0884]
#  [2797.415 ]
#  [2799.9648]
#  [2800.0757]
#  [2802.1501]
#  [2795.2107]
#  [2799.0276]
#  [2788.2112]
#  [2771.5127]
#  [2776.0244]
#  [2768.6694]
#  [2786.5757]
#  [2781.539 ]
#  [2797.4888]
#  [2791.673 ]
#  [2764.6511]
#  [2739.7085]
#  [2754.524 ]
#  [2742.3638]
#  [2747.166 ]
#  [2734.1667]
#  [2749.258 ]
#  [2757.1394]
#  [2756.949 ]
#  [2769.7727]
#  [2764.8865]
#  [2754.886 ]
#  [2760.7234]
#  [2759.713 ]
#  [2759.9026]
#  [2752.7725]
#  [2756.8032]
#  [2763.7893]
#  [2744.5896]
#  [2747.4421]
#  [2747.0125]
#  [2750.4924]
#  [2752.6438]
#  [2721.6448]
#  [2713.8503]
#  [2728.938 ]
#  [2729.3477]
#  [2741.554 ]
#  [2741.862 ]
#  [2746.4153]
#  [2749.7788]
#  [2760.7988]
#  [2752.061 ]
#  [2755.4263]
#  [2757.3804]
#  [2751.6304]
#  [2739.6128]
#  [2752.7275]
#  [2762.6538]
#  [2768.438 ]
#  [2753.0854]
#  [2763.932 ]
#  [2770.1707]
#  [2781.0588]
#  [2772.8271]
#  [2771.4082]
#  [2757.438 ]
#  [2756.0845]
#  [2771.7637]
#  [2769.21  ]
#  [2768.7764]
#  [2773.6191]
#  [2788.1692]
#  [2788.798 ]
#  [2788.1365]
#  [2799.009 ]
#  [2824.9382]
#  [2823.249 ]
#  [2820.42  ]
#  [2817.3813]
#  [2826.7832]
#  [2826.5984]
#  [2834.9292]
#  [2846.1152]
#  [2853.749 ]
#  [2856.3115]
#  [2841.8843]
#  [2845.8398]
#  [2844.699 ]
#  [2844.2827]
#  [2846.0457]
#  [2833.031 ]
#  [2836.916 ]
#  [2839.3398]
#  [2830.8804]
#  [2859.3743]
#  [2859.1848]
#  [2861.2827]
#  [2864.2817]
#  [2881.7854]
#  [2882.094 ]
#  [2867.9893]
#  [2861.587 ]
#  [2850.647 ]
#  [2854.1316]
#  [2839.0623]
#  [2851.8066]
#  [2850.8518]
#  [2856.4788]
#  [2849.2285]
#  [2846.7424]
#  [2834.858 ]
#  [2847.8318]
#  [2860.8225]
#  [2859.8347]
#  [2902.2139]
#  [2866.9517]
#  [2853.0437]
#  [2835.4023]
#  [2845.1267]
#  [2853.4866]
#  [2892.3774]
#  [2888.5977]
#  [2900.2847]
#  [2905.6018]
#  [2915.525 ]
#  [2908.4336]
#  [2902.6133]
#  [2907.5825]
#  [2906.1602]
#  [2899.6523]
#  [2887.916 ]
#  [2866.3489]
#  [2855.1838]
#  [2861.9778]
#  [2823.0496]
#  [2844.7422]
#  [2827.7117]
#  [2848.3748]
#  [2837.8208]
#  [2827.332 ]
#  [2842.2747]
#  [2856.8494]
#  [2839.335 ]
#  [2835.0898]
#  [2844.4084]
#  [2836.3047]
#  [2855.1514]
#  [2861.4429]
#  [2890.8408]
#  [2867.62  ]
#  [2845.751 ]
#  [2849.5977]
#  [2858.9998]
#  [2851.7168]
#  [2857.7886]
#  [2876.8887]
#  [2895.8706]
#  [2917.9722]
#  [2923.669 ]
#  [2905.7676]
#  [2898.763 ]
#  [2889.4001]
#  [2863.5513]
#  [2880.0005]
#  [2890.0325]
#  [2878.8442]
#  [2893.7612]
#  [2897.8252]
#  [2894.146 ]
#  [2909.0813]
#  [2890.4436]
#  [2893.287 ]
#  [2883.99  ]
#  [2894.3655]
#  [2886.1423]
#  [2868.167 ]
#  [2869.0742]
#  [2867.1821]
#  [2869.4497]
#  [2877.648 ]
#  [2850.5874]
#  [2846.882 ]
#  [2858.4487]
#  [2862.889 ]
#  [2864.9568]
#  [2856.8362]
#  [2863.4849]
#  [2869.3774]
#  [2847.4004]
#  [2858.624 ]
#  [2866.3555]
#  [2866.4294]
#  [2866.8452]
#  [2871.8984]
#  [2866.169 ]
#  [2850.6208]
#  [2852.8809]
#  [2857.4773]
#  [2838.2808]
#  [2848.7876]
#  [2857.1042]
#  [2868.7393]
#  [2871.2224]
#  [2869.1313]
#  [2878.7395]
#  [2870.5242]
#  [2877.0295]
#  [2875.7476]
#  [2879.2405]
#  [2874.9712]
#  [2879.442 ]
#  [2873.6292]
#  [2873.443 ]
#  [2878.5498]
#  [2902.9697]
#  [2894.3313]
#  [2897.5242]
#  [2895.0825]
#  [2894.571 ]
#  [2894.4443]
#  [2894.513 ]
#  [2894.786 ]
#  [2907.6033]
#  [2920.02  ]
#  [2920.5986]
#  [2916.5237]
#  [2922.167 ]
#  [2925.8745]
#  [2921.47  ]
#  [2916.0806]
#  [2913.2847]
#  [2915.6077]
#  [2924.5552]
#  [2927.865 ]
#  [2928.143 ]
#  [2942.893 ]
#  [2930.8828]
#  [2927.7366]
#  [2938.4077]
#  [2939.853 ]
#  [2951.0654]
#  [2962.7427]
#  [2968.558 ]
#  [2963.5894]
#  [2970.2976]
#  [2973.521 ]
#  [2965.4033]
#  [2961.349 ]
#  [2962.655 ]
#  [2963.567 ]
#  [2964.9124]
#  [2965.0955]
#  [2953.791 ]
#  [2956.2737]
#  [2924.5703]
#  [2935.132 ]
#  [2931.9258]
#  [2936.488 ]
#  [2935.4592]
#  [2962.4976]
#  [2980.1582]
#  [2995.1592]
#  [2997.4534]
#  [2993.6123]
#  [3008.2644]
#  [3016.3237]
#  [3014.398 ]
#  [3014.2637]
#  [3005.3335]
#  [3001.9797]
#  [3028.0024]
#  [3041.9673]
#  [3025.3691]
#  [3026.6587]
#  [3028.188 ]
#  [3035.095 ]
#  [3028.8745]
#  [3028.787 ]
#  [3042.541 ]
#  [3048.3462]
#  [3048.026 ]
#  [3052.62  ]
#  [3056.0347]
#  [3050.9937]
#  [3036.9607]
#  [3035.0083]
#  [3025.4084]
#  [3033.254 ]
#  [3040.0337]
#  [3038.0098]
#  [3039.583 ]
#  [3043.415 ]
#  [3040.4355]
#  [3042.842 ]
#  [3037.6948]]

# %%
# plot 

plot_time_series(train_predict, test_predict, prices, time_step)

# %% [markdown]
# # Ethereum LSTM with Simpler Model

# %%
def create_simple_model():
    model = Sequential()
    model.add(LSTM(50, return_sequences=False, input_shape=(time_step, 1)))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
time_step = 10

prices = json_to_prices('time_series_modeling/data/ethereum90days.json')
normalized_prices = normalize_prices(prices)
training_data, test_data = split_data(normalized_prices)
X_train, y_train = create_dataset(training_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)
lstm = create_simple_model()

lstm.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 54/54 [==============================] - 2s 13ms/step - loss: 0.0956 - val_loss: 1.0740
# Epoch 2/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0103 - val_loss: 0.4862
# Epoch 3/50
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0095 - val_loss: 0.4951
# Epoch 4/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0091 - val_loss: 0.3924
# Epoch 5/50
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0085 - val_loss: 0.3311
# Epoch 6/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0080 - val_loss: 0.3657
# Epoch 7/50
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0074 - val_loss: 0.2554
# Epoch 8/50
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0068 - val_loss: 0.2423
# Epoch 9/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0063 - val_loss: 0.2203
# Epoch 10/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 0.2657
# Epoch 11/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 0.2513
# Epoch 12/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0054 - val_loss: 0.2059
# Epoch 13/50
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0052 - val_loss: 0.1807
# Epoch 14/50
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0051 - val_loss: 0.1333
# Epoch 15/50
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0049 - val_loss: 0.1191
# Epoch 16/50
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0047 - val_loss: 0.1420
# Epoch 17/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0047 - val_loss: 0.0942
# Epoch 18/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0045 - val_loss: 0.0949
# Epoch 19/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0044 - val_loss: 0.0778
# Epoch 20/50
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0044 - val_loss: 0.0873
# Epoch 21/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0041 - val_loss: 0.0755
# Epoch 22/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0040 - val_loss: 0.0821
# Epoch 23/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0038 - val_loss: 0.0648
# Epoch 24/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0037 - val_loss: 0.1087
# Epoch 25/50
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0038 - val_loss: 0.0608
# Epoch 26/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0035 - val_loss: 0.0634
# Epoch 27/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0035 - val_loss: 0.0661
# Epoch 28/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0034 - val_loss: 0.0621
# Epoch 29/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0033 - val_loss: 0.0605
# Epoch 30/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0032 - val_loss: 0.0802
# Epoch 31/50
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 0.0570
# Epoch 32/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0032 - val_loss: 0.0629
# Epoch 33/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0032 - val_loss: 0.0436
# Epoch 34/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0031 - val_loss: 0.0398
# Epoch 35/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0029 - val_loss: 0.0539
# Epoch 36/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0030 - val_loss: 0.0413
# Epoch 37/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0030 - val_loss: 0.0472
# Epoch 38/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0028 - val_loss: 0.0387
# Epoch 39/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0029 - val_loss: 0.0451
# Epoch 40/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0028 - val_loss: 0.0377
# Epoch 41/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0027 - val_loss: 0.0397
# Epoch 42/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0028 - val_loss: 0.0316
# Epoch 43/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0027 - val_loss: 0.0290
# Epoch 44/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0026 - val_loss: 0.0365
# Epoch 45/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0027 - val_loss: 0.0231
# Epoch 46/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0026 - val_loss: 0.0258
# Epoch 47/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0026 - val_loss: 0.0199
# Epoch 48/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0026 - val_loss: 0.0359
# Epoch 49/50
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0025 - val_loss: 0.0179
# Epoch 50/50
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0026 - val_loss: 0.0239

# %%
predictions(lstm, X_train, y_train, X_test, y_test, prices)
# Out:
# 54/54 [==============================] - 0s 2ms/step
# 14/14 [==============================] - 0s 2ms/step
# Train Score: 12.93506077759598937860 RMSE
# Test Score: 39.55521056366510634916 RMSE
# (array([[2041.107 ],
#         [2045.6344],
#         [2038.0079],
#         ...,
#         [2487.3074],
#         [2485.089 ],
#         [2495.3975]], dtype=float32),
#  array([[2486.7808],
#         [2488.7065],
#         [2490.9014],
#         [2491.4893],
#         [2490.7468],
#         [2484.7961],
#         [2489.8682],
#         [2492.8525],
#         [2504.9849],
#         [2509.0496],
#         [2499.5737],
#         [2497.6113],
#         [2499.324 ],
#         [2504.2512],
#         [2504.61  ],
#         [2522.2424],
#         [2517.1318],
#         [2521.176 ],
#         [2526.2485],
#         [2525.4683],
#         [2524.0107],
#         [2521.469 ],
#         [2521.8997],
#         [2528.2495],
#         [2522.7588],
#         [2513.0017],
#         [2512.9724],
#         [2509.8086],
#         [2507.7402],
#         [2510.4253],
#         [2512.4375],
#         [2507.8076],
#         [2495.6687],
#         [2501.181 ],
#         [2499.6091],
#         [2505.056 ],
#         [2509.883 ],
#         [2513.0103],
#         [2500.7383],
#         [2499.0317],
#         [2493.3447],
#         [2493.245 ],
#         [2493.6582],
#         [2498.4753],
#         [2490.1453],
#         [2476.0166],
#         [2476.6873],
#         [2483.1414],
#         [2488.6064],
#         [2484.815 ],
#         [2520.5288],
#         [2555.0828],
#         [2551.553 ],
#         [2595.9998],
#         [2614.9312],
#         [2611.4067],
#         [2632.3403],
#         [2627.946 ],
#         [2650.8506],
#         [2653.8755],
#         [2661.2993],
#         [2670.4534],
#         [2656.8213],
#         [2640.575 ],
#         [2642.795 ],
#         [2646.8354],
#         [2642.8218],
#         [2645.11  ],
#         [2655.2092],
#         [2671.8408],
#         [2664.8555],
#         [2673.5222],
#         [2671.2012],
#         [2643.8804],
#         [2627.312 ],
#         [2628.816 ],
#         [2609.4988],
#         [2612.541 ],
#         [2624.826 ],
#         [2615.5608],
#         [2623.273 ],
#         [2628.3083],
#         [2633.2976],
#         [2637.646 ],
#         [2628.9688],
#         [2621.8892],
#         [2628.4277],
#         [2633.9495],
#         [2626.828 ],
#         [2635.8328],
#         [2641.1018],
#         [2649.0215],
#         [2696.8882],
#         [2732.8057],
#         [2744.936 ],
#         [2750.6375],
#         [2738.9272],
#         [2750.0261],
#         [2755.5117],
#         [2736.535 ],
#         [2736.5864],
#         [2736.5996],
#         [2740.4404],
#         [2751.4692],
#         [2754.2632],
#         [2770.7668],
#         [2766.8892],
#         [2769.433 ],
#         [2799.1467],
#         [2780.1384],
#         [2780.9402],
#         [2789.91  ],
#         [2778.4368],
#         [2765.0645],
#         [2766.317 ],
#         [2765.0269],
#         [2771.899 ],
#         [2776.9114],
#         [2788.3306],
#         [2785.8523],
#         [2785.7349],
#         [2796.9385],
#         [2824.951 ],
#         [2817.6191],
#         [2817.5784],
#         [2812.592 ],
#         [2809.4578],
#         [2819.516 ],
#         [2817.8125],
#         [2808.9502],
#         [2804.2434],
#         [2807.1895],
#         [2822.0994],
#         [2828.4329],
#         [2829.6692],
#         [2831.936 ],
#         [2826.6548],
#         [2828.3503],
#         [2819.712 ],
#         [2802.8662],
#         [2802.1794],
#         [2796.64  ],
#         [2809.6716],
#         [2809.7075],
#         [2822.544 ],
#         [2821.4343],
#         [2797.237 ],
#         [2769.3418],
#         [2774.0486],
#         [2766.7212],
#         [2767.4924],
#         [2757.6682],
#         [2766.71  ],
#         [2776.7578],
#         [2778.5728],
#         [2789.5676],
#         [2788.2793],
#         [2778.9097],
#         [2781.6055],
#         [2781.9177],
#         [2781.9163],
#         [2776.0063],
#         [2777.845 ],
#         [2784.6917],
#         [2770.083 ],
#         [2767.8877],
#         [2767.7073],
#         [2770.48  ],
#         [2773.0515],
#         [2747.461 ],
#         [2733.3574],
#         [2742.8984],
#         [2746.5435],
#         [2757.041 ],
#         [2760.3245],
#         [2764.6562],
#         [2768.6833],
#         [2779.1133],
#         [2773.8152],
#         [2775.2305],
#         [2777.882 ],
#         [2773.5427],
#         [2762.1045],
#         [2770.3936],
#         [2781.8967],
#         [2789.563 ],
#         [2778.021 ],
#         [2784.0598],
#         [2791.8572],
#         [2803.0342],
#         [2798.5024],
#         [2795.868 ],
#         [2783.7073],
#         [2779.2224],
#         [2791.884 ],
#         [2793.3616],
#         [2792.8477],
#         [2797.1052],
#         [2811.0261],
#         [2815.1274],
#         [2815.1038],
#         [2824.8328],
#         [2850.9636],
#         [2855.8823],
#         [2854.019 ],
#         [2851.4712],
#         [2859.6924],
#         [2862.057 ],
#         [2869.9375],
#         [2882.4785],
#         [2892.8643],
#         [2897.9841],
#         [2886.4585],
#         [2887.0088],
#         [2886.9312],
#         [2886.466 ],
#         [2888.038 ],
#         [2877.3687],
#         [2877.5007],
#         [2880.2434],
#         [2873.3965],
#         [2895.9995],
#         [2903.0864],
#         [2905.8323],
#         [2909.5884],
#         [2926.6226],
#         [2931.5598],
#         [2919.8765],
#         [2911.4338],
#         [2900.1543],
#         [2900.113 ],
#         [2887.4019],
#         [2894.0793],
#         [2896.1943],
#         [2901.0605],
#         [2896.1155],
#         [2891.978 ],
#         [2880.6133],
#         [2888.2715],
#         [2902.5688],
#         [2905.2632],
#         [2944.062 ],
#         [2922.9495],
#         [2903.875 ],
#         [2884.5532],
#         [2887.3752],
#         [2896.1785],
#         [2933.065 ],
#         [2940.2515],
#         [2951.8188],
#         [2960.7722],
#         [2972.0156],
#         [2968.496 ],
#         [2962.5967],
#         [2966.538 ],
#         [2966.979 ],
#         [2961.3562],
#         [2949.43  ],
#         [2927.3115],
#         [2910.914 ],
#         [2911.999 ],
#         [2879.6318],
#         [2885.6829],
#         [2875.732 ],
#         [2888.0166],
#         [2883.6743],
#         [2871.8257],
#         [2880.95  ],
#         [2896.9895],
#         [2885.5146],
#         [2877.6045],
#         [2884.3647],
#         [2879.4182],
#         [2893.9702],
#         [2904.245 ],
#         [2933.1797],
#         [2920.0847],
#         [2896.6465],
#         [2894.2908],
#         [2902.7769],
#         [2898.5667],
#         [2902.2312],
#         [2920.949 ],
#         [2943.5117],
#         [2969.5806],
#         [2981.1975],
#         [2967.559 ],
#         [2958.8157],
#         [2949.1284],
#         [2923.6187],
#         [2930.567 ],
#         [2943.064 ],
#         [2936.2383],
#         [2946.774 ],
#         [2954.213 ],
#         [2952.2273],
#         [2964.992 ],
#         [2952.0378],
#         [2950.3718],
#         [2942.7134],
#         [2949.42  ],
#         [2944.4414],
#         [2926.7297],
#         [2922.247 ],
#         [2919.8809],
#         [2920.7366],
#         [2927.9316],
#         [2906.4595],
#         [2895.8594],
#         [2903.5767],
#         [2909.772 ],
#         [2912.5925],
#         [2906.1934],
#         [2910.0286],
#         [2916.751 ],
#         [2898.9885],
#         [2902.9478],
#         [2912.1133],
#         [2914.4302],
#         [2915.1584],
#         [2919.9917],
#         [2916.379 ],
#         [2901.5127],
#         [2899.1555],
#         [2903.0227],
#         [2887.416 ],
#         [2891.245 ],
#         [2900.647 ],
#         [2913.1807],
#         [2918.7068],
#         [2918.022 ],
#         [2926.5059],
#         [2921.8281],
#         [2926.0464],
#         [2926.5598],
#         [2929.8347],
#         [2927.278 ],
#         [2930.535 ],
#         [2926.6023],
#         [2925.099 ],
#         [2929.505 ],
#         [2952.79  ],
#         [2951.5166],
#         [2953.383 ],
#         [2952.5269],
#         [2951.862 ],
#         [2951.7515],
#         [2951.8604],
#         [2952.2947],
#         [2964.165 ],
#         [2979.1165],
#         [2983.4097],
#         [2980.8464],
#         [2985.762 ],
#         [2990.9707],
#         [2988.332 ],
#         [2982.8484],
#         [2979.2192],
#         [2980.6057],
#         [2989.192 ],
#         [2994.556 ],
#         [2996.0913],
#         [3010.23  ],
#         [3003.3916],
#         [2998.249 ],
#         [3007.2666],
#         [3011.3281],
#         [3022.4907],
#         [3036.767 ],
#         [3046.0295],
#         [3044.0134],
#         [3050.3682],
#         [3055.6958],
#         [3049.6072],
#         [3044.6455],
#         [3045.106 ],
#         [3046.2888],
#         [3047.7773],
#         [3048.3433],
#         [3038.1594],
#         [3037.5117],
#         [3009.2507],
#         [3009.21  ],
#         [3007.5413],
#         [3009.985 ],
#         [3009.6748],
#         [3033.8667],
#         [3057.3687],
#         [3076.935 ],
#         [3084.1118],
#         [3082.8835],
#         [3098.1772],
#         [3110.538 ],
#         [3111.6892],
#         [3112.823 ],
#         [3105.825 ],
#         [3101.571 ],
#         [3125.9387],
#         [3145.622 ],
#         [3133.1204],
#         [3132.521 ],
#         [3135.4592],
#         [3142.801 ],
#         [3138.5027],
#         [3137.4365],
#         [3151.17  ],
#         [3160.2637],
#         [3161.6445],
#         [3166.8645],
#         [3172.1262],
#         [3168.6528],
#         [3154.7554],
#         [3150.1646],
#         [3140.3738],
#         [3144.8025],
#         [3152.3135],
#         [3151.4082],
#         [3152.4924],
#         [3156.7312],
#         [3154.7705],
#         [3156.5571],
#         [3152.2935]], dtype=float32))

# %%
# testing model on 2022 data

time_step = 10
prices = json_to_prices('time_series_modeling/data/ethereum90days.json')
training_data = normalize_prices(prices)
X_train, y_train = create_dataset(training_data, time_step)

test_prices = json_to_prices('time_series_modeling/data/ethereum2022test.json')
test_data = normalize_prices(test_prices)

X_test, y_test = create_dataset(test_data, time_step)
lstm = create_model()

lstm.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 68/68 [==============================] - 4s 16ms/step - loss: 0.1202 - val_loss: 2.7086
# Epoch 2/50
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0148 - val_loss: 2.5249
# Epoch 3/50
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0117 - val_loss: 2.4865
# Epoch 4/50
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0107 - val_loss: 2.4594
# Epoch 5/50
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0104 - val_loss: 2.3772
# Epoch 6/50
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0103 - val_loss: 2.3714
# Epoch 7/50
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0091 - val_loss: 2.2970
# Epoch 8/50
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0086 - val_loss: 2.3141
# Epoch 9/50
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0083 - val_loss: 2.3318
# Epoch 10/50
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0079 - val_loss: 2.4458
# Epoch 11/50
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0079 - val_loss: 2.3697
# Epoch 12/50
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0071 - val_loss: 2.3349
# Epoch 13/50
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0077 - val_loss: 2.2565
# Epoch 14/50
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0070 - val_loss: 2.1832
# Epoch 15/50
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0070 - val_loss: 2.1610
# Epoch 16/50
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0061 - val_loss: 2.1218
# Epoch 17/50
# 68/68 [==============================] - 1s 8ms/step - loss: 0.0061 - val_loss: 2.0886
# Epoch 18/50
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0060 - val_loss: 2.0620
# Epoch 19/50
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0066 - val_loss: 1.9682
# Epoch 20/50
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0054 - val_loss: 1.8927
# Epoch 21/50
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0051 - val_loss: 1.8117
# Epoch 22/50
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0055 - val_loss: 1.7073
# Epoch 23/50
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0050 - val_loss: 1.5701
# Epoch 24/50
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0046 - val_loss: 1.4953
# Epoch 25/50
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 1.4049
# Epoch 26/50
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 1.3017
# Epoch 27/50
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0047 - val_loss: 1.1815
# Epoch 28/50
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0038 - val_loss: 1.0061
# Epoch 29/50
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0040 - val_loss: 0.9331
# Epoch 30/50
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0041 - val_loss: 0.9402
# Epoch 31/50
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0036 - val_loss: 0.8068
# Epoch 32/50
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0040 - val_loss: 0.8051
# Epoch 33/50
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0034 - val_loss: 0.7357
# Epoch 34/50
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0033 - val_loss: 0.6826
# Epoch 35/50
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0031 - val_loss: 0.6309
# Epoch 36/50
# 68/68 [==============================] - 1s 8ms/step - loss: 0.0031 - val_loss: 0.6225
# Epoch 37/50
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0031 - val_loss: 0.5867
# Epoch 38/50
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0035 - val_loss: 0.6532
# Epoch 39/50
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0033 - val_loss: 0.6170
# Epoch 40/50
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0030 - val_loss: 0.5708
# Epoch 41/50
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0030 - val_loss: 0.5611
# Epoch 42/50
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0032 - val_loss: 0.5593
# Epoch 43/50
# 68/68 [==============================] - 1s 8ms/step - loss: 0.0031 - val_loss: 0.5667
# Epoch 44/50
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0030 - val_loss: 0.5629
# Epoch 45/50
# 68/68 [==============================] - 1s 8ms/step - loss: 0.0031 - val_loss: 0.5752
# Epoch 46/50
# 68/68 [==============================] - 1s 8ms/step - loss: 0.0030 - val_loss: 0.5151
# Epoch 47/50
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0033 - val_loss: 0.5385
# Epoch 48/50
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0031 - val_loss: 0.5828
# Epoch 49/50
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0031 - val_loss: 0.5688
# Epoch 50/50
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0031 - val_loss: 0.5707

# %%
predictions(lstm, X_train, y_train, X_test, y_test, prices)
# Out:
# 68/68 [==============================] - 1s 2ms/step
# 1/1 [==============================] - 0s 20ms/step
# Train Score: 15.21722211230432009188 RMSE
# Test Score: 193.19273820601324587187 RMSE
# (array([[2046.2256],
#         [2051.101 ],
#         [2044.659 ],
#         ...,
#         [3222.3408],
#         [3226.4863],
#         [3218.06  ]], dtype=float32),
#  array([[2562.6904],
#         [2815.5415],
#         [2905.7583],
#         [2872.0647],
#         [2778.484 ],
#         [2694.2993],
#         [2401.036 ],
#         [2089.0464],
#         [1998.0178],
#         [2068.6326],
#         [2178.0754],
#         [2176.979 ],
#         [2318.7725]], dtype=float32))

# %% [markdown]
# # DAI Univariate LSTM Time Series

# %%
time_step = 10

prices = json_to_prices('time_series_modeling/data/dai90days.json')
normalized_prices = normalize_prices(prices)
training_data, test_data = split_data(normalized_prices)
X_train, y_train = create_dataset(training_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)
lstm = create_model()

lstm.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 54/54 [==============================] - 4s 20ms/step - loss: 0.8694 - val_loss: 1.1332
# Epoch 2/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.8443 - val_loss: 1.1121
# Epoch 3/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.8326 - val_loss: 1.1185
# Epoch 4/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.8227 - val_loss: 1.1330
# Epoch 5/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.8137 - val_loss: 1.1278
# Epoch 6/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.8042 - val_loss: 1.1338
# Epoch 7/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.8018 - val_loss: 1.1518
# Epoch 8/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7950 - val_loss: 1.1659
# Epoch 9/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.7977 - val_loss: 1.1670
# Epoch 10/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7959 - val_loss: 1.1738
# Epoch 11/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7947 - val_loss: 1.1651
# Epoch 12/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7960 - val_loss: 1.1801
# Epoch 13/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7949 - val_loss: 1.1657
# Epoch 14/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7926 - val_loss: 1.1916
# Epoch 15/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7959 - val_loss: 1.1844
# Epoch 16/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7928 - val_loss: 1.1803
# Epoch 17/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7907 - val_loss: 1.1735
# Epoch 18/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7944 - val_loss: 1.1869
# Epoch 19/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7901 - val_loss: 1.1798
# Epoch 20/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7920 - val_loss: 1.2047
# Epoch 21/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7874 - val_loss: 1.1823
# Epoch 22/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7872 - val_loss: 1.1925
# Epoch 23/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7898 - val_loss: 1.1828
# Epoch 24/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7837 - val_loss: 1.1904
# Epoch 25/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7808 - val_loss: 1.2097
# Epoch 26/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7790 - val_loss: 1.1901
# Epoch 27/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7794 - val_loss: 1.2108
# Epoch 28/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7762 - val_loss: 1.1780
# Epoch 29/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.7712 - val_loss: 1.2395
# Epoch 30/50
# 54/54 [==============================] - 0s 9ms/step - loss: 0.7683 - val_loss: 1.2232
# Epoch 31/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7633 - val_loss: 1.2174
# Epoch 32/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7629 - val_loss: 1.1987
# Epoch 33/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7653 - val_loss: 1.2340
# Epoch 34/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.7624 - val_loss: 1.1936
# Epoch 35/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7552 - val_loss: 1.2435
# Epoch 36/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7539 - val_loss: 1.2310
# Epoch 37/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7555 - val_loss: 1.2265
# Epoch 38/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.7464 - val_loss: 1.1963
# Epoch 39/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7492 - val_loss: 1.2236
# Epoch 40/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7427 - val_loss: 1.2989
# Epoch 41/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7456 - val_loss: 1.3115
# Epoch 42/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7393 - val_loss: 1.2266
# Epoch 43/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7384 - val_loss: 1.2729
# Epoch 44/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7242 - val_loss: 1.3293
# Epoch 45/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7252 - val_loss: 1.3598
# Epoch 46/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.7286 - val_loss: 1.2525
# Epoch 47/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7143 - val_loss: 1.3335
# Epoch 48/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7126 - val_loss: 1.2713
# Epoch 49/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.7012 - val_loss: 1.2278
# Epoch 50/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.7028 - val_loss: 1.4179

# %%
predictions(lstm, X_train, y_train, X_test, y_test, prices)
# Out:
# 54/54 [==============================] - 1s 3ms/step
# 14/14 [==============================] - 0s 4ms/step
# Train Score: 0.00102208565685368694 RMSE
# Test Score: 0.00143763647894762283 RMSE
# (array([[0.998244  ],
#         [0.99809456],
#         [0.9981376 ],
#         ...,
#         [0.9995385 ],
#         [0.9994799 ],
#         [0.99941075]], dtype=float32),
#  array([[0.9996675 ],
#         [0.99984246],
#         [0.999565  ],
#         [0.99993664],
#         [0.9998579 ],
#         [0.99961   ],
#         [0.9999547 ],
#         [0.9998314 ],
#         [0.9997874 ],
#         [0.99961704],
#         [0.9997485 ],
#         [0.9997332 ],
#         [1.0000385 ],
#         [0.99947923],
#         [0.9997459 ],
#         [1.000243  ],
#         [0.9995077 ],
#         [0.9991618 ],
#         [1.0001595 ],
#         [1.0000381 ],
#         [0.9999559 ],
#         [0.9999561 ],
#         [0.9996035 ],
#         [1.0000774 ],
#         [1.000021  ],
#         [0.9997341 ],
#         [1.0003717 ],
#         [0.9998115 ],
#         [0.99912316],
#         [0.99943566],
#         [0.99945307],
#         [0.99950165],
#         [0.9993519 ],
#         [0.999385  ],
#         [0.9992885 ],
#         [0.99929225],
#         [0.99946713],
#         [0.9995996 ],
#         [0.9995307 ],
#         [0.999431  ],
#         [0.9995744 ],
#         [0.9993605 ],
#         [0.9995134 ],
#         [0.9993181 ],
#         [1.0000314 ],
#         [0.9993633 ],
#         [0.9995242 ],
#         [0.9993065 ],
#         [0.9992456 ],
#         [0.9990641 ],
#         [0.9990726 ],
#         [0.9994783 ],
#         [0.9992515 ],
#         [0.999059  ],
#         [0.99933994],
#         [0.99850285],
#         [0.99915063],
#         [0.9992891 ],
#         [0.9993509 ],
#         [0.9988745 ],
#         [0.99929667],
#         [0.99923444],
#         [0.9992769 ],
#         [0.99924076],
#         [0.9992713 ],
#         [0.9994306 ],
#         [0.9990099 ],
#         [0.9993015 ],
#         [0.9991733 ],
#         [0.9993279 ],
#         [0.9991631 ],
#         [0.99938655],
#         [0.99967855],
#         [0.99943876],
#         [0.99966735],
#         [0.99970156],
#         [0.9998363 ],
#         [0.99984336],
#         [1.000066  ],
#         [0.99818635],
#         [0.9995437 ],
#         [1.0002359 ],
#         [1.0003237 ],
#         [1.0000967 ],
#         [0.99977154],
#         [1.0000124 ],
#         [0.9998674 ],
#         [0.99995565],
#         [1.000054  ],
#         [0.99903816],
#         [0.9992664 ],
#         [0.99982864],
#         [0.99944246],
#         [0.9996001 ],
#         [0.9994605 ],
#         [0.99928933],
#         [0.99810076],
#         [0.9993448 ],
#         [0.9998013 ],
#         [0.99945986],
#         [0.9990083 ],
#         [0.9989092 ],
#         [0.99883837],
#         [0.99957687],
#         [0.9991257 ],
#         [0.99924576],
#         [0.9994048 ],
#         [0.9989249 ],
#         [0.99948907],
#         [0.9997241 ],
#         [0.9996203 ],
#         [0.9993021 ],
#         [0.999613  ],
#         [0.9994741 ],
#         [0.9997698 ],
#         [0.99962586],
#         [0.9983385 ],
#         [0.99930185],
#         [0.999625  ],
#         [0.9998896 ],
#         [0.9995313 ],
#         [0.9991395 ],
#         [0.9994912 ],
#         [0.99955344],
#         [0.9996055 ],
#         [0.9994334 ],
#         [0.9992341 ],
#         [0.9994669 ],
#         [0.9996917 ],
#         [0.9998043 ],
#         [0.99951947],
#         [0.9998516 ],
#         [0.9996156 ],
#         [1.0000387 ],
#         [0.9995839 ],
#         [1.0004689 ],
#         [0.999093  ],
#         [0.99792373],
#         [0.99912286],
#         [1.0000166 ],
#         [0.9997059 ],
#         [0.9995337 ],
#         [0.9993557 ],
#         [0.9992637 ],
#         [0.9993256 ],
#         [0.9994122 ],
#         [0.99935967],
#         [0.99931514],
#         [0.9995    ],
#         [0.99949145],
#         [0.999484  ],
#         [0.9996688 ],
#         [0.9995578 ],
#         [0.99965334],
#         [0.99954975],
#         [0.9996752 ],
#         [0.9992615 ],
#         [0.9991878 ],
#         [0.99929535],
#         [0.99940693],
#         [0.99887854],
#         [0.9990912 ],
#         [0.9992883 ],
#         [0.9992673 ],
#         [0.99927026],
#         [0.999202  ],
#         [0.999209  ],
#         [0.9989667 ],
#         [0.9989657 ],
#         [0.9989136 ],
#         [0.99889255],
#         [0.99882597],
#         [0.99876094],
#         [0.9985951 ],
#         [0.99863774],
#         [0.998977  ],
#         [0.999019  ],
#         [0.99876285],
#         [0.99891585],
#         [0.9990341 ],
#         [0.9991228 ],
#         [0.9990838 ],
#         [0.99907   ],
#         [0.9989358 ],
#         [0.99911207],
#         [0.998937  ],
#         [0.999055  ],
#         [0.99907064],
#         [0.9993535 ],
#         [0.9991153 ],
#         [0.99900687],
#         [0.9989653 ],
#         [0.9991823 ],
#         [0.9992115 ],
#         [0.9992371 ],
#         [0.9991982 ],
#         [0.9992028 ],
#         [0.99918264],
#         [0.99912727],
#         [0.9992597 ],
#         [0.9992841 ],
#         [0.99936247],
#         [0.9993744 ],
#         [0.9994279 ],
#         [0.99966896],
#         [0.9992801 ],
#         [0.9997587 ],
#         [0.9996102 ],
#         [0.99951744],
#         [0.9995799 ],
#         [0.99983734],
#         [0.9997957 ],
#         [0.99950767],
#         [0.9997625 ],
#         [0.9995793 ],
#         [0.99959815],
#         [0.9992404 ],
#         [0.99935466],
#         [0.9991391 ],
#         [0.9992081 ],
#         [0.9981478 ],
#         [0.99888545],
#         [1.0000737 ],
#         [0.99946743],
#         [0.99966127],
#         [1.0000707 ],
#         [0.99976707],
#         [1.0017715 ],
#         [1.0001512 ],
#         [1.001073  ],
#         [0.9981557 ],
#         [0.9981003 ],
#         [1.0013981 ],
#         [1.0001013 ],
#         [0.99809694],
#         [0.9991617 ],
#         [0.9991929 ],
#         [0.99920106],
#         [0.9996691 ],
#         [0.99927247],
#         [0.9999083 ],
#         [0.9996014 ],
#         [0.9993543 ],
#         [0.9997884 ],
#         [0.9997401 ],
#         [0.99986106],
#         [0.99935734],
#         [0.99895227],
#         [0.9986214 ],
#         [0.9988652 ],
#         [0.9984292 ],
#         [0.99868   ],
#         [0.9984383 ],
#         [0.9986018 ],
#         [0.9988798 ],
#         [0.99896604],
#         [0.9990393 ],
#         [0.9991237 ],
#         [0.99913824],
#         [0.9992289 ],
#         [0.9991498 ],
#         [0.99904007],
#         [0.9993901 ],
#         [0.99956006],
#         [0.9996492 ],
#         [0.9996086 ],
#         [0.99880946],
#         [0.9992548 ],
#         [1.0003514 ],
#         [1.0012125 ],
#         [0.9976984 ],
#         [0.999375  ],
#         [1.0015792 ],
#         [1.0021766 ],
#         [1.0034801 ],
#         [1.0013977 ],
#         [0.99841875],
#         [0.9984626 ],
#         [0.99943817],
#         [0.9989078 ],
#         [0.9990239 ],
#         [0.9989479 ],
#         [0.99894524],
#         [0.9998069 ],
#         [1.001545  ],
#         [0.9970305 ],
#         [0.99931973],
#         [1.0005165 ],
#         [1.0005813 ],
#         [1.0004549 ],
#         [1.0007012 ],
#         [1.0005941 ],
#         [1.0001023 ],
#         [0.9987171 ],
#         [0.9999061 ],
#         [0.9994854 ],
#         [1.0003467 ],
#         [0.9997756 ],
#         [1.0004238 ],
#         [0.99993235],
#         [1.0009699 ],
#         [1.0010326 ],
#         [0.9994816 ],
#         [0.9991549 ],
#         [0.9998702 ],
#         [1.0003853 ],
#         [1.0002139 ],
#         [1.0002601 ],
#         [0.9998988 ],
#         [0.9996016 ],
#         [0.99929416],
#         [0.9988349 ],
#         [0.9996714 ],
#         [0.9997051 ],
#         [0.99940366],
#         [0.9994599 ],
#         [0.99897116],
#         [0.99958533],
#         [0.9989578 ],
#         [0.9994261 ],
#         [0.9995784 ],
#         [0.9996481 ],
#         [0.99952716],
#         [0.9995797 ],
#         [0.99931556],
#         [0.99974096],
#         [0.9991102 ],
#         [0.9998585 ],
#         [0.99938804],
#         [0.9995689 ],
#         [0.99987125],
#         [0.99922395],
#         [0.9997545 ],
#         [0.999617  ],
#         [0.9998278 ],
#         [0.99949574],
#         [1.0004839 ],
#         [0.9992482 ],
#         [0.9988657 ],
#         [0.9993277 ],
#         [0.99950147],
#         [0.9995949 ],
#         [0.9992682 ],
#         [0.9992737 ],
#         [0.9988056 ],
#         [0.99907714],
#         [0.99938256],
#         [0.9992332 ],
#         [0.9989686 ],
#         [0.998918  ],
#         [0.998866  ],
#         [0.99883854],
#         [0.9988505 ],
#         [0.99887073],
#         [0.9989138 ],
#         [0.99884206],
#         [0.9988262 ],
#         [0.9988336 ],
#         [0.9989305 ],
#         [0.9991378 ],
#         [0.9993093 ],
#         [0.99931246],
#         [0.9994038 ],
#         [0.9994944 ],
#         [0.9995804 ],
#         [0.9997515 ],
#         [0.9999873 ],
#         [1.0008187 ],
#         [0.9991472 ],
#         [1.0004289 ],
#         [1.0008548 ],
#         [0.9991859 ],
#         [0.99838233],
#         [0.9988938 ],
#         [0.9989434 ],
#         [1.0007429 ],
#         [1.0007328 ],
#         [1.0003853 ],
#         [0.99979746],
#         [0.9997441 ],
#         [1.0001127 ],
#         [1.0002086 ],
#         [0.99948543],
#         [1.0002841 ],
#         [0.99962544],
#         [0.9997313 ],
#         [0.99989545],
#         [0.99975085],
#         [0.999719  ],
#         [0.9996073 ],
#         [1.0004718 ],
#         [0.99967957],
#         [0.9975359 ],
#         [1.0001429 ],
#         [1.0020275 ],
#         [1.0026009 ],
#         [0.99685   ],
#         [0.9993589 ],
#         [1.0002235 ],
#         [1.0001938 ],
#         [1.0006503 ],
#         [1.0010096 ],
#         [1.001422  ],
#         [0.99962485],
#         [0.9992642 ],
#         [0.99890816],
#         [0.9984795 ],
#         [0.9989527 ],
#         [0.9992679 ],
#         [0.9994615 ],
#         [0.9994536 ],
#         [0.999385  ],
#         [0.9993343 ],
#         [0.99958163],
#         [0.99947363],
#         [1.0003115 ],
#         [1.0023394 ],
#         [1.0012598 ],
#         [0.99748665],
#         [0.9991443 ],
#         [1.00109   ],
#         [1.0018895 ],
#         [0.9976208 ]], dtype=float32))

# %% [markdown]
# # USDT Univariate LSTM Time Series

# %%
time_step = 10

prices = json_to_prices('time_series_modeling/data/usdt90days.json')
normalized_prices = normalize_prices(prices)
training_data, test_data = split_data(normalized_prices)
X_train, y_train = create_dataset(training_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)
lstm = create_model()

lstm.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 54/54 [==============================] - 4s 19ms/step - loss: 0.6928 - val_loss: 1.2805
# Epoch 2/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6668 - val_loss: 1.2699
# Epoch 3/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6712 - val_loss: 1.2815
# Epoch 4/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6660 - val_loss: 1.2665
# Epoch 5/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.6624 - val_loss: 1.2596
# Epoch 6/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.6627 - val_loss: 1.2689
# Epoch 7/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6605 - val_loss: 1.2521
# Epoch 8/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.6632 - val_loss: 1.2556
# Epoch 9/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6618 - val_loss: 1.2556
# Epoch 10/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6616 - val_loss: 1.2599
# Epoch 11/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6603 - val_loss: 1.2566
# Epoch 12/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6580 - val_loss: 1.2619
# Epoch 13/50
# 54/54 [==============================] - 1s 10ms/step - loss: 0.6568 - val_loss: 1.2576
# Epoch 14/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.6593 - val_loss: 1.2629
# Epoch 15/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6575 - val_loss: 1.2541
# Epoch 16/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6563 - val_loss: 1.2666
# Epoch 17/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.6567 - val_loss: 1.2656
# Epoch 18/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6563 - val_loss: 1.2545
# Epoch 19/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6556 - val_loss: 1.2604
# Epoch 20/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6570 - val_loss: 1.2619
# Epoch 21/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6555 - val_loss: 1.2609
# Epoch 22/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.6571 - val_loss: 1.2603
# Epoch 23/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.6539 - val_loss: 1.2650
# Epoch 24/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6539 - val_loss: 1.2696
# Epoch 25/50
# 54/54 [==============================] - 1s 9ms/step - loss: 0.6502 - val_loss: 1.2691
# Epoch 26/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6543 - val_loss: 1.2588
# Epoch 27/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6540 - val_loss: 1.2696
# Epoch 28/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6529 - val_loss: 1.2647
# Epoch 29/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6540 - val_loss: 1.2574
# Epoch 30/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6521 - val_loss: 1.2858
# Epoch 31/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6515 - val_loss: 1.2689
# Epoch 32/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6511 - val_loss: 1.2619
# Epoch 33/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.6507 - val_loss: 1.2769
# Epoch 34/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.6507 - val_loss: 1.2918
# Epoch 35/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.6464 - val_loss: 1.2621
# Epoch 36/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.6596 - val_loss: 1.2705
# Epoch 37/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6457 - val_loss: 1.2845
# Epoch 38/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6469 - val_loss: 1.2855
# Epoch 39/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.6411 - val_loss: 1.2784
# Epoch 40/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6376 - val_loss: 1.2800
# Epoch 41/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6331 - val_loss: 1.2915
# Epoch 42/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6240 - val_loss: 1.3347
# Epoch 43/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6492 - val_loss: 1.3314
# Epoch 44/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6438 - val_loss: 1.3036
# Epoch 45/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6297 - val_loss: 1.2881
# Epoch 46/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6220 - val_loss: 1.2902
# Epoch 47/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6259 - val_loss: 1.3030
# Epoch 48/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6174 - val_loss: 1.3167
# Epoch 49/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6219 - val_loss: 1.2862
# Epoch 50/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.6166 - val_loss: 1.3287

# %%
predictions(lstm, X_train, y_train, X_test, y_test, prices)
# Out:
# 54/54 [==============================] - 1s 3ms/step
# 14/14 [==============================] - 0s 3ms/step
# (1718, 1) (422, 1)
# Train Score: 0.00076027879587659106 RMSE
# Test Score: 0.00112487286319954728 RMSE
# (array([[1.0002648],
#         [1.000151 ],
#         [1.0000945],
#         ...,
#         [1.0002849],
#         [1.0003129],
#         [1.0002791]], dtype=float32),
#  array([[1.000402  ],
#         [1.0003011 ],
#         [1.0004803 ],
#         [1.0004481 ],
#         [1.0003768 ],
#         [1.000366  ],
#         [1.0003431 ],
#         [1.0002494 ],
#         [1.000233  ],
#         [1.0001478 ],
#         [1.0002388 ],
#         [1.0002427 ],
#         [1.0001582 ],
#         [1.0001829 ],
#         [1.0001062 ],
#         [1.0000339 ],
#         [0.99997044],
#         [0.99997795],
#         [1.0001967 ],
#         [1.0000372 ],
#         [1.0000682 ],
#         [1.0000352 ],
#         [1.000147  ],
#         [1.0001085 ],
#         [1.0002463 ],
#         [1.0002345 ],
#         [1.0002037 ],
#         [1.0001705 ],
#         [1.0001099 ],
#         [1.0001419 ],
#         [1.0000811 ],
#         [1.000176  ],
#         [1.0001094 ],
#         [1.0002507 ],
#         [1.0001098 ],
#         [1.0001208 ],
#         [1.0001137 ],
#         [1.0002067 ],
#         [1.0003258 ],
#         [1.0002044 ],
#         [1.0001394 ],
#         [1.0001653 ],
#         [1.0000554 ],
#         [0.99987835],
#         [0.999806  ],
#         [0.9996981 ],
#         [0.99965084],
#         [0.9998941 ],
#         [0.99975973],
#         [0.99973214],
#         [0.99968743],
#         [1.0000128 ],
#         [1.0002023 ],
#         [1.0000457 ],
#         [1.0001026 ],
#         [1.0001079 ],
#         [1.0000681 ],
#         [0.999981  ],
#         [1.0000076 ],
#         [1.0001903 ],
#         [0.9999923 ],
#         [1.000039  ],
#         [1.0000325 ],
#         [1.0000523 ],
#         [1.000084  ],
#         [1.0001931 ],
#         [1.0001043 ],
#         [1.0005188 ],
#         [1.0002114 ],
#         [1.0001962 ],
#         [1.0002087 ],
#         [1.0002033 ],
#         [1.0002685 ],
#         [1.000297  ],
#         [1.0002346 ],
#         [1.0002016 ],
#         [1.0000571 ],
#         [1.0000132 ],
#         [1.0000367 ],
#         [0.9999687 ],
#         [1.0000106 ],
#         [0.9998741 ],
#         [0.9998297 ],
#         [0.9996784 ],
#         [0.9997896 ],
#         [0.99957335],
#         [0.9996832 ],
#         [1.0000606 ],
#         [0.99995637],
#         [0.99984485],
#         [1.0006225 ],
#         [1.0003469 ],
#         [1.0006193 ],
#         [1.0008706 ],
#         [1.0007658 ],
#         [1.0003992 ],
#         [1.0002319 ],
#         [1.0004709 ],
#         [1.0001097 ],
#         [1.000049  ],
#         [1.0002272 ],
#         [1.0002561 ],
#         [1.0002955 ],
#         [1.0001653 ],
#         [1.0000442 ],
#         [0.99989665],
#         [0.99992156],
#         [0.9998483 ],
#         [0.99972415],
#         [0.99969757],
#         [0.9997364 ],
#         [0.9999062 ],
#         [0.99970454],
#         [0.99968046],
#         [0.99966186],
#         [0.9997964 ],
#         [0.9999942 ],
#         [0.9996979 ],
#         [1.0000479 ],
#         [0.9999015 ],
#         [0.99994445],
#         [0.99991566],
#         [1.0000336 ],
#         [1.0000018 ],
#         [0.999898  ],
#         [0.99969435],
#         [0.99948394],
#         [0.9993784 ],
#         [0.9993907 ],
#         [0.99926126],
#         [0.99929464],
#         [0.9992557 ],
#         [0.99942076],
#         [0.99944115],
#         [0.9994198 ],
#         [0.9995241 ],
#         [0.99979067],
#         [0.99953026],
#         [0.99979776],
#         [0.99975914],
#         [0.99989504],
#         [0.9999424 ],
#         [1.0000434 ],
#         [0.9999642 ],
#         [0.99993277],
#         [0.9999132 ],
#         [0.99983907],
#         [0.99980575],
#         [0.99988973],
#         [0.9998175 ],
#         [0.9997887 ],
#         [0.99983007],
#         [0.9997796 ],
#         [0.9997729 ],
#         [0.99977446],
#         [0.9997807 ],
#         [0.9997574 ],
#         [0.9998282 ],
#         [0.9997487 ],
#         [0.99973464],
#         [0.9997379 ],
#         [0.9997715 ],
#         [0.9998898 ],
#         [0.9997974 ],
#         [0.9997373 ],
#         [0.99982005],
#         [0.9998065 ],
#         [0.9998411 ],
#         [0.9997511 ],
#         [0.99970204],
#         [0.9998186 ],
#         [1.0000876 ],
#         [0.9996534 ],
#         [0.9997779 ],
#         [0.9998819 ],
#         [1.0000178 ],
#         [1.0000359 ],
#         [1.0001127 ],
#         [1.0001724 ],
#         [1.000145  ],
#         [1.0001152 ],
#         [1.0000153 ],
#         [1.0000745 ],
#         [0.99996585],
#         [0.9999146 ],
#         [0.999849  ],
#         [0.99988043],
#         [0.9998536 ],
#         [0.9998905 ],
#         [0.99986017],
#         [0.99976873],
#         [0.9998279 ],
#         [0.99965245],
#         [0.999687  ],
#         [0.9997063 ],
#         [0.99960446],
#         [0.99956244],
#         [0.99962664],
#         [0.9997082 ],
#         [0.99967086],
#         [0.9996904 ],
#         [0.9996503 ],
#         [0.9997119 ],
#         [0.9996619 ],
#         [0.9996407 ],
#         [0.99971515],
#         [0.9996991 ],
#         [0.9996572 ],
#         [0.9998574 ],
#         [1.0002402 ],
#         [0.9998874 ],
#         [0.99997485],
#         [1.000438  ],
#         [1.0003844 ],
#         [1.0007716 ],
#         [1.0007439 ],
#         [1.00105   ],
#         [1.0007108 ],
#         [1.0006815 ],
#         [1.0015067 ],
#         [1.0011728 ],
#         [1.0000966 ],
#         [1.0007168 ],
#         [1.0004115 ],
#         [1.0002034 ],
#         [1.0001252 ],
#         [1.0001514 ],
#         [1.0001881 ],
#         [1.0004408 ],
#         [1.0006148 ],
#         [1.0004457 ],
#         [1.0002152 ],
#         [1.0003917 ],
#         [1.0002354 ],
#         [1.0001783 ],
#         [1.0001558 ],
#         [1.0000904 ],
#         [0.9999355 ],
#         [0.99980074],
#         [0.99970484],
#         [0.9996793 ],
#         [0.9998122 ],
#         [0.9996087 ],
#         [0.99983686],
#         [0.99988556],
#         [0.99992234],
#         [0.9999363 ],
#         [0.99998856],
#         [1.0001035 ],
#         [1.0001007 ],
#         [1.0004574 ],
#         [1.0002472 ],
#         [1.0002986 ],
#         [1.000293  ],
#         [1.0003284 ],
#         [1.0004224 ],
#         [1.0010766 ],
#         [1.0005816 ],
#         [1.0020484 ],
#         [1.0013376 ],
#         [1.0027851 ],
#         [1.002588  ],
#         [1.0005987 ],
#         [0.99765646],
#         [0.99799854],
#         [0.99914193],
#         [0.99973446],
#         [1.0002633 ],
#         [1.000608  ],
#         [1.0006084 ],
#         [1.0006701 ],
#         [1.0004122 ],
#         [1.0008335 ],
#         [1.0007275 ],
#         [1.0008988 ],
#         [1.0010046 ],
#         [1.0005143 ],
#         [0.9997641 ],
#         [1.0002594 ],
#         [1.0005155 ],
#         [1.0005879 ],
#         [1.0004317 ],
#         [1.0005772 ],
#         [1.0003911 ],
#         [1.0000916 ],
#         [0.9998948 ],
#         [0.99989367],
#         [1.0003855 ],
#         [1.0008234 ],
#         [1.0006047 ],
#         [1.0007517 ],
#         [1.0006526 ],
#         [1.0000926 ],
#         [1.0000726 ],
#         [1.0001915 ],
#         [0.99993134],
#         [0.9998049 ],
#         [0.9998996 ],
#         [0.9996807 ],
#         [1.0001315 ],
#         [1.0000441 ],
#         [1.0000267 ],
#         [1.0001515 ],
#         [1.0001032 ],
#         [1.0002267 ],
#         [1.0001515 ],
#         [1.0002573 ],
#         [1.0002248 ],
#         [1.0001683 ],
#         [1.0001043 ],
#         [1.0011079 ],
#         [1.0002751 ],
#         [1.0006347 ],
#         [1.0009494 ],
#         [1.0010976 ],
#         [1.0010067 ],
#         [1.0005568 ],
#         [0.9998695 ],
#         [0.99999243],
#         [1.0005249 ],
#         [1.0005692 ],
#         [1.0006754 ],
#         [1.000666  ],
#         [1.0006652 ],
#         [1.0007478 ],
#         [1.0007918 ],
#         [1.0007141 ],
#         [1.000688  ],
#         [1.0006713 ],
#         [1.0006028 ],
#         [1.0006058 ],
#         [1.0007595 ],
#         [1.0008185 ],
#         [1.0008307 ],
#         [1.0006983 ],
#         [1.0006077 ],
#         [1.0005217 ],
#         [1.000486  ],
#         [1.0005985 ],
#         [1.000466  ],
#         [1.0004628 ],
#         [1.0003438 ],
#         [1.0003071 ],
#         [1.0002913 ],
#         [1.0002321 ],
#         [1.0001829 ],
#         [1.0002018 ],
#         [1.0002598 ],
#         [1.0002029 ],
#         [1.0002327 ],
#         [1.0002651 ],
#         [1.000334  ],
#         [1.0002915 ],
#         [1.0003595 ],
#         [1.0005493 ],
#         [1.0003933 ],
#         [1.000413  ],
#         [1.0004268 ],
#         [1.0003916 ],
#         [1.0004076 ],
#         [1.0002604 ],
#         [1.0003699 ],
#         [1.000286  ],
#         [1.0001756 ],
#         [1.0002378 ],
#         [1.0002489 ],
#         [1.0002393 ],
#         [1.0002989 ],
#         [1.0003533 ],
#         [1.0001452 ],
#         [1.0002705 ],
#         [1.0001976 ],
#         [1.0002272 ],
#         [1.0004696 ],
#         [1.000543  ],
#         [1.000304  ],
#         [1.0005542 ],
#         [1.0009556 ],
#         [1.0008868 ],
#         [1.0008228 ],
#         [1.0008538 ],
#         [1.0009053 ],
#         [1.0009682 ],
#         [1.0004236 ],
#         [1.0006367 ],
#         [1.0003781 ],
#         [1.0007224 ],
#         [1.0013744 ],
#         [1.0011458 ],
#         [0.9998399 ],
#         [0.999691  ],
#         [1.0009727 ],
#         [1.0004157 ],
#         [0.999892  ],
#         [1.0001239 ],
#         [1.0001136 ],
#         [0.99989825],
#         [1.0001022 ],
#         [1.0002577 ],
#         [1.0002574 ],
#         [1.0005753 ],
#         [1.0001013 ],
#         [1.0004654 ],
#         [1.0007894 ],
#         [1.0008388 ],
#         [1.0007386 ],
#         [1.0006816 ],
#         [1.000903  ],
#         [1.000845  ],
#         [1.0008107 ],
#         [1.0013546 ],
#         [1.0005741 ],
#         [1.0005976 ],
#         [1.0007637 ],
#         [1.0008408 ],
#         [1.0008764 ],
#         [1.0005275 ],
#         [1.0011014 ],
#         [1.0013963 ],
#         [1.0016038 ],
#         [1.0013148 ],
#         [1.0009152 ]], dtype=float32))

# %% [markdown]
# ## Generalized Ethereum Model
#
# April 27, 2023 - March 27, 2024
#
# 1682571600(april) -  1687842000(june)
#
# 1687842000(june) - 1693112400(august)
#
# 1693112400(august) - october(1698382800)
#
# 1698382800(october) - 	1703656800 (december)
#
# 1703656800 (december) - 1709013600(feb 2024)
#
# 1709013600(feb 2024) - 1711515600(march 2024)

# %%
prices_1 = json_to_prices('time_series_modeling/general_model_data/eth_april_june.json')
prices_2 = json_to_prices('time_series_modeling/general_model_data/eth_june_august.json')
prices_3 = json_to_prices('time_series_modeling/general_model_data/eth_august_october.json')
prices_4 = json_to_prices('time_series_modeling/general_model_data/eth_october_december.json')
prices_5 = json_to_prices('time_series_modeling/general_model_data/eth_december_feb.json')
prices_6 = json_to_prices('time_series_modeling/general_model_data/eth_feb_march.json')

# %%
print(prices_1)
# Out:
# 0       1909.047327
# 1       1913.866964
# 2       1888.625330
# 3       1886.630519
# 4       1887.228688
#            ...
# 1460    1859.802420
# 1461    1863.036554
# 1462    1863.721617
# 1463    1867.575185
# 1464    1873.661023
# Name: price, Length: 1465, dtype: float64

# %%
# want to combine all the data into one dataframe
prices = pd.concat([prices_1, prices_2, prices_3, prices_4, prices_5, prices_6])

#reset the index
prices = prices.reset_index(drop=True)
print(prices)
# Out:
# 0       1909.047327
# 1       1913.866964
# 2       1888.625330
# 3       1886.630519
# 4       1887.228688
#            ...
# 8036    3583.853827
# 8037    3612.419591
# 8038    3601.360086
# 8039    3617.079283
# 8040    3605.308078
# Name: price, Length: 8041, dtype: float64

# %%
time_step = 10
training_data = normalize_prices(prices)
X_train, y_train = create_dataset(training_data, time_step)

test_prices = json_to_prices('time_series_modeling/data/ethereum2022test.json')
test_data = normalize_prices(test_prices)

X_test, y_test = create_dataset(test_data, time_step)
lstm = create_model()

lstm.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 251/251 [==============================] - 5s 9ms/step - loss: 0.0286 - val_loss: 2.4501
# Epoch 2/50
# 251/251 [==============================] - 2s 6ms/step - loss: 0.0025 - val_loss: 2.4910
# Epoch 3/50
# 251/251 [==============================] - 2s 6ms/step - loss: 0.0029 - val_loss: 2.3950
# Epoch 4/50
# 251/251 [==============================] - 2s 6ms/step - loss: 0.0023 - val_loss: 2.3271
# Epoch 5/50
# 251/251 [==============================] - 1s 6ms/step - loss: 0.0022 - val_loss: 2.3136
# Epoch 6/50
# 251/251 [==============================] - 2s 6ms/step - loss: 0.0019 - val_loss: 2.2492
# Epoch 7/50
# 251/251 [==============================] - 2s 6ms/step - loss: 0.0019 - val_loss: 2.1794
# Epoch 8/50
# 251/251 [==============================] - 2s 7ms/step - loss: 0.0016 - val_loss: 2.1200
# Epoch 9/50
# 251/251 [==============================] - 2s 6ms/step - loss: 0.0018 - val_loss: 2.0323
# Epoch 10/50
# 251/251 [==============================] - 2s 6ms/step - loss: 0.0016 - val_loss: 1.9237
# Epoch 11/50
# 251/251 [==============================] - 2s 6ms/step - loss: 0.0015 - val_loss: 1.8781
# Epoch 12/50
# 251/251 [==============================] - 2s 6ms/step - loss: 0.0013 - val_loss: 1.8773
# Epoch 13/50
# 251/251 [==============================] - 2s 7ms/step - loss: 0.0014 - val_loss: 1.7241
# Epoch 14/50
# 251/251 [==============================] - 2s 7ms/step - loss: 0.0013 - val_loss: 1.6276
# Epoch 15/50
# 251/251 [==============================] - 2s 7ms/step - loss: 0.0013 - val_loss: 1.5360
# Epoch 16/50
# 251/251 [==============================] - 2s 7ms/step - loss: 9.7178e-04 - val_loss: 1.4544
# Epoch 17/50
# 251/251 [==============================] - 2s 6ms/step - loss: 0.0011 - val_loss: 1.3686
# Epoch 18/50
# 251/251 [==============================] - 2s 6ms/step - loss: 0.0010 - val_loss: 1.2670
# Epoch 19/50
# 251/251 [==============================] - 2s 6ms/step - loss: 9.1060e-04 - val_loss: 1.1882
# Epoch 20/50
# 251/251 [==============================] - 2s 6ms/step - loss: 8.8831e-04 - val_loss: 1.1203
# Epoch 21/50
# 251/251 [==============================] - 2s 6ms/step - loss: 8.0078e-04 - val_loss: 1.0662
# Epoch 22/50
# 251/251 [==============================] - 2s 6ms/step - loss: 7.6388e-04 - val_loss: 0.9881
# Epoch 23/50
# 251/251 [==============================] - 2s 6ms/step - loss: 9.1910e-04 - val_loss: 0.9418
# Epoch 24/50
# 251/251 [==============================] - 2s 6ms/step - loss: 6.9886e-04 - val_loss: 0.9055
# Epoch 25/50
# 251/251 [==============================] - 2s 6ms/step - loss: 8.3465e-04 - val_loss: 0.8472
# Epoch 26/50
# 251/251 [==============================] - 2s 6ms/step - loss: 7.8186e-04 - val_loss: 0.8269
# Epoch 27/50
# 251/251 [==============================] - 2s 7ms/step - loss: 7.0337e-04 - val_loss: 0.7634
# Epoch 28/50
# 251/251 [==============================] - 2s 6ms/step - loss: 7.6305e-04 - val_loss: 0.7348
# Epoch 29/50
# 251/251 [==============================] - 2s 6ms/step - loss: 7.0005e-04 - val_loss: 0.7183
# Epoch 30/50
# 251/251 [==============================] - 2s 6ms/step - loss: 7.0153e-04 - val_loss: 0.6774
# Epoch 31/50
# 251/251 [==============================] - 2s 6ms/step - loss: 7.8339e-04 - val_loss: 0.6605
# Epoch 32/50
# 251/251 [==============================] - 2s 6ms/step - loss: 7.1664e-04 - val_loss: 0.6328
# Epoch 33/50
# 251/251 [==============================] - 2s 7ms/step - loss: 7.5843e-04 - val_loss: 0.6214
# Epoch 34/50
# 251/251 [==============================] - 2s 6ms/step - loss: 6.5864e-04 - val_loss: 0.6011
# Epoch 35/50
# 251/251 [==============================] - 2s 6ms/step - loss: 7.2785e-04 - val_loss: 0.5640
# Epoch 36/50
# 251/251 [==============================] - 2s 6ms/step - loss: 7.6861e-04 - val_loss: 0.5740
# Epoch 37/50
# 251/251 [==============================] - 2s 7ms/step - loss: 6.6477e-04 - val_loss: 0.5570
# Epoch 38/50
# 251/251 [==============================] - 2s 7ms/step - loss: 7.1446e-04 - val_loss: 0.5453
# Epoch 39/50
# 251/251 [==============================] - 2s 7ms/step - loss: 7.1064e-04 - val_loss: 0.5258
# Epoch 40/50
# 251/251 [==============================] - 2s 6ms/step - loss: 6.5060e-04 - val_loss: 0.5381
# Epoch 41/50
# 251/251 [==============================] - 2s 7ms/step - loss: 6.9516e-04 - val_loss: 0.5365
# Epoch 42/50
# 251/251 [==============================] - 2s 7ms/step - loss: 6.2275e-04 - val_loss: 0.5330
# Epoch 43/50
# 251/251 [==============================] - 2s 6ms/step - loss: 7.0907e-04 - val_loss: 0.5170
# Epoch 44/50
# 251/251 [==============================] - 2s 6ms/step - loss: 6.8029e-04 - val_loss: 0.5099
# Epoch 45/50
# 251/251 [==============================] - 2s 6ms/step - loss: 7.0739e-04 - val_loss: 0.5122
# Epoch 46/50
# 251/251 [==============================] - 2s 6ms/step - loss: 6.7464e-04 - val_loss: 0.4899
# Epoch 47/50
# 251/251 [==============================] - 2s 6ms/step - loss: 6.7983e-04 - val_loss: 0.5101
# Epoch 48/50
# 251/251 [==============================] - 2s 6ms/step - loss: 6.4986e-04 - val_loss: 0.5123
# Epoch 49/50
# 251/251 [==============================] - 2s 6ms/step - loss: 7.4711e-04 - val_loss: 0.4895
# Epoch 50/50
# 251/251 [==============================] - 2s 6ms/step - loss: 6.6469e-04 - val_loss: 0.5222

# %%
predictions(lstm, X_train, y_train, X_test, y_test, prices)
# Out:
# 251/251 [==============================] - 1s 2ms/step
# 1/1 [==============================] - 0s 20ms/step
# Train Score: 14.33170004420416709934 RMSE
# Test Score: 405.82552758941773163315 RMSE
# Test Predictions: [[2462.918 ]
#  [3071.3914]
#  [3249.8315]
#  [3125.2222]
#  [2895.8257]
#  [2715.7725]
#  [2020.1674]
#  [1307.9578]
#  [1197.2078]
#  [1446.9895]
#  [1595.2866]
#  [1553.1523]
#  [1861.2118]]
# (array([[1880.3231],
#         [1884.699 ],
#         [1890.4893],
#         ...,
#         [3623.1147],
#         [3612.0134],
#         [3628.0044]], dtype=float32),
#  array([[2462.918 ],
#         [3071.3914],
#         [3249.8315],
#         [3125.2222],
#         [2895.8257],
#         [2715.7725],
#         [2020.1674],
#         [1307.9578],
#         [1197.2078],
#         [1446.9895],
#         [1595.2866],
#         [1553.1523],
#         [1861.2118]], dtype=float32))

# %% [markdown]
# # Tables
#
# stablecoinpredicto, data used, training score, testing score
